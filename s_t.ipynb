# %% [markdown]
# Speech to Text Recognition

# %%
# !pip install pydub
# !pip install SpeechRecognition pydub
# Out:
# ...
#      |████████████████████████████████| 32.8 MB 146 kB/s
# ...

# %% [markdown]
# Here the drive is getiing mounted for the data to be extracted from it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing some packages
#import youtube_dl
#import google
import os
#import ffmpy
#import moviepy.editor as mp
import speech_recognition as sr
#from os import path
from pydub import AudioSegment
#from pydub.silence import split_on_silence

# %%
#import youtube_dl
#import google
import os
#import ffmpy
#import moviepy.editor as mp
import speech_recognition as sr
#from os import 
import glob

# %%
# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 200,
        # adjust this per requirement
        silence_thresh = sound.dBFS-16,
        # keep the silence for 1 second, adjustable as well
        keep_silence=100,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
                text_file = open("/content/data.txt", "w+")
                text_file.write(whole_text)
                text_file.close()
    return text_file

# %%
r = sr.Recognizer()
whole_text = ""

# %% [markdown]
# Data Set Courtesy:https://github.com/AI4Bharat/NPTEL2020-Indian-English-Speech-Dataset

# %%
list1 = glob.glob(r"/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/"+"*.wav")

# %%
print(list1)
# Out:
# ['/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00079c44375d42a50227e41d35de2b904c5530d1ebb912646b19fbe5.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/0005680e7ac8826cff24f15022b67a2651acd691bf897bf3d3e44345.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/000ac7ec9733de8ec34ca1c202a1815555ea3da32b55be34bd57c6b2.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00076c8b06d0a23b4dc920e4f4a6ce0568f2dcbf45777bd390b5f328.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00090638d3f9953f1af8eeb55c9bbec234e287de3d63b8adb7b02893.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/000a296951585e947aba6701aa75f4d597c9c70a22cbd17150aacd1b.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/000656c6275864186cd9842d6f9b17e53314cf8ac65ba64ef4b009c7.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/0008a4b7060b5940db0b2e7201c11f77306446eed4afa9f273cc436b.wav', '/content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/0008e32
# ...

# %%
whole_text= ""

# %% [markdown]
# The Final output (text) is stored in /content/sample.data/data.txt/

# %%
def srforall(path):
  global whole_text
  with sr.AudioFile(path) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened,language="en-US")
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(path , ":", text)
                whole_text = whole_text + text
                text_file = open("/content/drive/MyDrive/data_test_2.txt", "w+")
                text_file.write(whole_text)
                text_file.close()
  #Time complxity is N^n

# %%
for f in list1:
  
  srforall(f)
# Out:
# /content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00079c44375d42a50227e41d35de2b904c5530d1ebb912646b19fbe5.wav : Pull out full of tests and the code test so this is another test that will look into.
# /content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/0005680e7ac8826cff24f15022b67a2651acd691bf897bf3d3e44345.wav : Introducing introducing this.
# /content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/000ac7ec9733de8ec34ca1c202a1815555ea3da32b55be34bd57c6b2.wav : Dsquared dd square gets cancelled with big medieval were here.
# /content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00076c8b06d0a23b4dc920e4f4a6ce0568f2dcbf45777bd390b5f328.wav : Don't spend in his book also gave that particle particle equations that are equations.
# /content/drive/MyDrive/nptel-pure-set/nptel-pure/wav/00090638d3f9953f1af8eeb55c9bbec234e287de3d63b8adb7b02893.wav : Some may not could depend heavily on age gender many other kinds of factors.
# ...

# %%
text_file = open("/content/drive/MyDrive/data_test_2.txt", "r")
body = text_file.read()

# %%
text_file.read()

# %%
print(text_file)

# %%
with open("/content/drive/MyDrive/data_test_2.txt", "r") as file:
  body = file.read()

# %%
body
